# %% [markdown]
# # Leitura das bibliotecas
# E dos datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

#verificando a versão do kelarn

# import sklearn

# !pip uninstall scikit-learn -y

# !pip install -U scikit-learn

# %%
dataset = pd.read_csv(r'C:\Users\lippe\Documents\Python Scripts\Regression\train.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df = dataset.copy()
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # Separação Treino e Teste

# %%
from sklearn.model_selection import train_test_split
X = df.drop('SalePrice',axis=1)
y = df.SalePrice

X_tr,X_ts,y_tr,y_ts = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Missing Values

# %%
null_values = X_tr.isnull().sum()[X_tr.isnull().sum() > 0]/len(X_tr)*100
null_values.sort_values(ascending= False)
# Out:
# PoolQC          99.591002
# MiscFeature     96.012270
# Alley           93.558282
# Fence           80.470348
# FireplaceQu     47.750511
# LotFrontage     18.711656
# GarageType       5.419223
# GarageYrBlt      5.419223
# GarageFinish     5.419223
# GarageQual       5.419223
# GarageCond       5.419223
# BsmtExposure     2.556237
# BsmtFinType1     2.556237
# BsmtFinType2     2.556237
# BsmtCond         2.556237
# BsmtQual         2.556237
# MasVnrArea       0.204499
# MasVnrType       0.204499
# Electrical       0.102249
# dtype: float64

# %% [markdown]
# Por terem tanto valores nulos, o que resta é pouco representativo para a base, vou excluir as seguintes colunas
#
# **PoolQC**: Pool quality
#
# **MiscFeature**: Miscellaneous feature not covered in other categories - Também não relevante
#
# **Alley**: Type of alley access to property - Não relevante

# %%
X_tr_o = X_tr.copy()
X_ts_o = X_ts.copy()

X_tr_o = X_tr_o.drop(columns=['PoolQC','MiscFeature','Alley'])
X_ts_o = X_ts_o.drop(columns=['PoolQC','MiscFeature','Alley'])
null_values = X_tr_o.isnull().sum()[X_tr_o.isnull().sum() > 0]/len(X_tr_o)*100
null_values.sort_values(ascending= False)
# Out:
# Fence           80.470348
# FireplaceQu     47.750511
# LotFrontage     18.711656
# GarageType       5.419223
# GarageYrBlt      5.419223
# GarageFinish     5.419223
# GarageQual       5.419223
# GarageCond       5.419223
# BsmtQual         2.556237
# BsmtCond         2.556237
# BsmtExposure     2.556237
# BsmtFinType1     2.556237
# BsmtFinType2     2.556237
# MasVnrType       0.204499
# MasVnrArea       0.204499
# Electrical       0.102249
# dtype: float64

# %% [markdown]
# As seguintes variáveis já possuem uma significante amostragem de valores não nulos. Faz sentido preencher a ausência por **"inexist"** nesses casos
#
# **FireplaceQu**: Fireplace quality
#
# **Fence**: Fence quality

# %%
X_tr_o[['FireplaceQu','Fence']] = X_tr_o[['FireplaceQu','Fence']].fillna('Inexist')
X_tr_o[['FireplaceQu','Fence']]
# Out:
#      FireplaceQu    Fence
# 615      Inexist    MnPrv
# 613      Inexist  Inexist
# 1303     Inexist  Inexist
# 486      Inexist  Inexist
# 561           TA  Inexist
# ...          ...      ...
# 1095          Gd  Inexist
# 1130          TA    MnPrv
# 1294     Inexist  Inexist
# 860           Gd    GdPrv
# 1126          TA  Inexist
#
# [978 rows x 2 columns]

# %% [markdown]
# **LotFrontage**: Linear feet of street connected to property

# %%
X_tr_o.LotFrontage.describe()
# Out:
# count    795.000000
# mean      70.284277
# std       25.532805
# min       21.000000
# 25%       59.500000
# 50%       70.000000
# 75%       80.000000
# max      313.000000
# Name: LotFrontage, dtype: float64

# %% [markdown]
# Comparar o preço médio da casa com LotFrontage nulo, com os normais

# %%
print('Preço médio nulo: ',y_tr[X_tr_o.LotFrontage.isna()].mean())
print('Preço médio n/nulo: ',y_tr[X_tr_o.LotFrontage.isna() == False].mean())
print('Diferença: ',(y_tr[X_tr_o.LotFrontage.isna()].mean()-y_tr[X_tr_o.LotFrontage.isna() == False].mean())/y_tr.mean()*100,'%')
# Out:
# Preço médio nulo:  181542.4863387978
# Preço médio n/nulo:  180932.8893081761
# Diferença:  0.33670659116431556 %

# %% [markdown]
# É possível ver que os valores, por serem nulos possuem um impacto na variável resposta, dessa forma vou tratar como um valor particular -1

# %%
plt.figure(figsize=(10,5))
plt.hist(y_tr[X_tr_o.LotFrontage.isna()], rwidth=0.9,bins=30, density=True,color= 'b', alpha=0.5)
plt.hist(y_tr[X_tr_o.LotFrontage.isna() == False], rwidth=0.9,bins=30, density=True,color= 'r', alpha=0.5);

# %%
X_tr_o.LotFrontage = X_tr_o.LotFrontage.fillna(-1)
X_ts_o.LotFrontage = X_ts_o.LotFrontage.fillna(-1)

# %%
null_values = X_tr_o.isnull().sum()[X_tr_o.isnull().sum() > 0]/len(X_tr_o)*100
null_values.sort_values(ascending= False)
# Out:
# GarageType      5.419223
# GarageYrBlt     5.419223
# GarageFinish    5.419223
# GarageQual      5.419223
# GarageCond      5.419223
# BsmtQual        2.556237
# BsmtCond        2.556237
# BsmtExposure    2.556237
# BsmtFinType1    2.556237
# BsmtFinType2    2.556237
# MasVnrType      0.204499
# MasVnrArea      0.204499
# Electrical      0.102249
# dtype: float64

# %% [markdown]
# Tratamento das variáveis relacionadas à garagem: Como os nulos são casas sem garagem, irei especificar em meu modelo
#
# **GarageType**: Garage location
#
# **GarageYrBlt**: Year garage was built
#
# **GarageFinish**: Interior finish of the garage
#
# **GarageCars**: Size of garage in car capacity - Altamente correlacionada com car GarageArea
#
# **GarageArea**: Size of garage in square feet - Altamente correlacionada com car GarageCars
#
# **GarageQual**: Garage quality
#
# **GarageCond**: Garage condition

# %%
garage_cols = X_tr_o.columns[(X_tr_o.columns).str.contains('Garage')]
for col,dtypes in X_tr_o[garage_cols].dtypes.items():
  if dtypes == 'object':
    X_tr_o[col] = X_tr_o[col].fillna('Inexist')
    X_ts_o[col] = X_ts_o[col].fillna('Inexist')
  else:
    X_tr_o[col] = X_tr_o[col].fillna(-1)
    X_ts_o[col] = X_ts_o[col].fillna(-1)
X_tr_o
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 615    616          85       RL         80.0     8800   Pave      Reg
# 613    614          20       RL         70.0     8402   Pave      Reg
# 1303  1304          20       RL         73.0     8688   Pave      Reg
# 486    487          20       RL         79.0    10289   Pave      Reg
# 561    562          20       RL         77.0    10010   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 1095  1096          20       RL         78.0     9317   Pave      IR1
# 1130  1131          50       RL         65.0     7804   Pave      Reg
# 1294  1295          20       RL         60.0     8172   Pave      Reg
# 860    861          50       RL         55.0     7642   Pave      Reg
# 1126  1127         120       RL         53.0     3684   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 615          Lvl    AllPub    Inside  ...             0         0           0
# 613          Lvl    AllPub    Inside  ...             0         0           0
# 1303         Lvl    AllPub    Inside  ...             0         0           0
# 486          Lvl    AllPub    Inside  ...             0         0           0
# 561          Lvl    AllPub    Inside  ...             0         0           0
# ...          ...       ...       ...  ...           ...       ...         ...
# 1095         Lvl    AllPub    Inside  ...             0         0           0
# 1130         Lvl    AllPub    Inside  ...             0         0           0
# 1294         Lvl    AllPub    Inside  ...             0         0           0
# 860          Lvl    AllPub    Corner  ...             0         0           0
# 1126         Lvl    AllPub    Inside  ...             0         0           0
#
#      PoolArea    Fence MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 615         0    MnPrv       0       5    2010        WD        Abnorml
# 613         0  Inexist       0      12    2007       New        Partial
# 1303        0  Inexist       0       4    2006        WD         Normal
# 486         0  Inexist       0       6    2007        WD         Normal
# 561         0  Inexist       0       4    2006        WD         Normal
# ...       ...      ...     ...     ...     ...       ...            ...
# 1095        0  Inexist       0       3    2007        WD         Normal
# 1130        0    MnPrv       0      12    2009        WD         Normal
# 1294        0  Inexist       0       4    2006        WD         Normal
# 860         0    GdPrv       0       6    2007        WD         Normal
# 1126        0  Inexist       0       6    2009        WD         Normal
#
# [978 rows x 77 columns]

# %% [markdown]
# O resto possui pouco parte dos dados como valores nulos, irei exclui-los

# %%
null_rows_tr = X_tr_o[X_tr_o.isnull().any(axis=1)].index
null_rows_ts = X_ts_o[X_ts_o.isnull().any(axis=1)].index

X_tr_o = X_tr_o.drop(null_rows_tr)
y_tr = y_tr.drop(null_rows_tr)

X_ts_o = X_ts_o.drop(null_rows_ts)
y_ts = y_ts.drop(null_rows_ts)

# %%
null_values = X_tr_o.isnull().sum()[X_tr_o.isnull().sum() > 0]/len(X_tr_o)*100
null_values.sort_values(ascending= False)
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Standalizing

# %%
from sklearn.preprocessing import RobustScaler

X_tr_std = X_tr_o.copy()
X_ts_std = X_ts_o.copy()


scalers = {}
for col,dtypes in X_tr_std.dtypes.items():
  if dtypes != 'object':
    scaler = RobustScaler()
    scaler.fit(X_tr_std[[col]])
    X_tr_std.loc[:,col] = scaler.transform(X_tr_std[[col]])
    X_ts_std.loc[:,col] = scaler.transform(X_ts_std[[col]])
    scalers[col] = scaler

X_tr_std
# Out:
#             Id  MSSubClass MSZoning  LotFrontage   LotArea Street LotShape  \
# 615  -0.152159         0.7       RL        0.425 -0.194446   Pave      Reg
# 613  -0.154817        -0.6       RL        0.175 -0.291183   Pave      Reg
# 1303  0.762126        -0.6       RL        0.250 -0.221669   Pave      Reg
# 486  -0.323588        -0.6       RL        0.400  0.167467   Pave      Reg
# 561  -0.223920        -0.6       RL        0.350  0.099654   Pave      Reg
# ...        ...         ...      ...          ...       ...    ...      ...
# 1095  0.485714        -0.6       RL        0.375 -0.068785   Pave      IR1
# 1130  0.532226         0.0       RL        0.050 -0.436532   Pave      Reg
# 1294  0.750166        -0.6       RL       -0.075 -0.347086   Pave      Reg
# 860   0.173422         0.0       RL       -0.200 -0.475907   Pave      Reg
# 1126  0.526910         1.4       RL       -0.250 -1.437929   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 615          Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# 613          Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# 1303         Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# 486          Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# 561          Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# ...          ...       ...       ...  ...           ...       ...         ...
# 1095         Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# 1130         Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# 1294         Lvl    AllPub    Inside  ...           0.0       0.0         0.0
# 860          Lvl    AllPub    Corner  ...           0.0       0.0         0.0
# 1126         Lvl    AllPub    Inside  ...           0.0       0.0         0.0
#
#      PoolArea    Fence MiscVal    MoSold  YrSold  SaleType  SaleCondition
# 615       0.0    MnPrv     0.0 -0.333333     1.0        WD        Abnorml
# 613       0.0  Inexist     0.0  2.000000    -0.5       New        Partial
# 1303      0.0  Inexist     0.0 -0.666667    -1.0        WD         Normal
# 486       0.0  Inexist     0.0  0.000000    -0.5        WD         Normal
# 561       0.0  Inexist     0.0 -0.666667    -1.0        WD         Normal
# ...       ...      ...     ...       ...     ...       ...            ...
# 1095      0.0  Inexist     0.0 -1.000000    -0.5        WD         Normal
# 1130      0.0    MnPrv     0.0  2.000000     0.5        WD         Normal
# 1294      0.0  Inexist     0.0 -0.666667    -1.0        WD         Normal
# 860       0.0    GdPrv     0.0  0.000000    -0.5        WD         Normal
# 1126      0.0  Inexist     0.0  0.000000     0.5        WD         Normal
#
# [950 rows x 77 columns]

# %% [markdown]
# # Encoding

# %% [markdown]
# Muitas das variáveis são ordinais, ou seja, que tenha uma sequência lógica. Elas extão padronizadas em:
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Vou fazer o encoding com base nisso.

# %%
from sklearn.preprocessing import OrdinalEncoder
X_tr_enc = X_tr_std.copy()
X_ts_enc = X_ts_std.copy()

encoder = {}
default_cat = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
for col,dtype in X_tr_enc.dtypes.items():
    if dtype == 'object':
      encoder[col] = OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value= -1,categories=[default_cat])
      X_tr_enc.loc[:,col] = encoder[col].fit_transform(X_tr_enc[[col]],)
      X_ts_enc.loc[:,col] = encoder[col].transform(X_ts_enc[[col]])

X_tr_enc
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 615  -0.152159         0.7      -1.0        0.425 -0.194446    -1.0      -1.0
# 613  -0.154817        -0.6      -1.0        0.175 -0.291183    -1.0      -1.0
# 1303  0.762126        -0.6      -1.0        0.250 -0.221669    -1.0      -1.0
# 486  -0.323588        -0.6      -1.0        0.400  0.167467    -1.0      -1.0
# 561  -0.223920        -0.6      -1.0        0.350  0.099654    -1.0      -1.0
# ...        ...         ...       ...          ...       ...     ...       ...
# 1095  0.485714        -0.6      -1.0        0.375 -0.068785    -1.0      -1.0
# 1130  0.532226         0.0      -1.0        0.050 -0.436532    -1.0      -1.0
# 1294  0.750166        -0.6      -1.0       -0.075 -0.347086    -1.0      -1.0
# 860   0.173422         0.0      -1.0       -0.200 -0.475907    -1.0      -1.0
# 1126  0.526910         1.4      -1.0       -0.250 -1.437929    -1.0      -1.0
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# 615          -1.0       -1.0       -1.0  ...            0.0        0.0
# 613          -1.0       -1.0       -1.0  ...            0.0        0.0
# 1303         -1.0       -1.0       -1.0  ...            0.0        0.0
# 486          -1.0       -1.0       -1.0  ...            0.0        0.0
# 561          -1.0       -1.0       -1.0  ...            0.0        0.0
# ...           ...        ...        ...  ...            ...        ...
# 1095         -1.0       -1.0       -1.0  ...            0.0        0.0
# 1130         -1.0       -1.0       -1.0  ...            0.0        0.0
# 1294         -1.0       -1.0       -1.0  ...            0.0        0.0
# 860          -1.0       -1.0       -1.0  ...            0.0        0.0
# 1126         -1.0       -1.0       -1.0  ...            0.0        0.0
#
#       ScreenPorch  PoolArea  Fence  MiscVal    MoSold  YrSold  SaleType  \
# 615           0.0       0.0   -1.0      0.0 -0.333333     1.0      -1.0
# 613           0.0       0.0   -1.0      0.0  2.000000    -0.5      -1.0
# 1303          0.0       0.0   -1.0      0.0 -0.666667    -1.0      -1.0
# 486           0.0       0.0   -1.0      0.0  0.000000    -0.5      -1.0
# 561           0.0       0.0   -1.0      0.0 -0.666667    -1.0      -1.0
# ...           ...       ...    ...      ...       ...     ...       ...
# 1095          0.0       0.0   -1.0      0.0 -1.000000    -0.5      -1.0
# 1130          0.0       0.0   -1.0      0.0  2.000000     0.5      -1.0
# 1294          0.0       0.0   -1.0      0.0 -0.666667    -1.0      -1.0
# 860           0.0       0.0   -1.0      0.0  0.000000    -0.5      -1.0
# 1126          0.0       0.0   -1.0      0.0  0.000000     0.5      -1.0
#
#       SaleCondition
# 615            -1.0
# 613            -1.0
# 1303           -1.0
# 486            -1.0
# 561            -1.0
# ...             ...
# 1095           -1.0
# 1130           -1.0
# 1294           -1.0
# 860            -1.0
# 1126           -1.0
#
# [950 rows x 77 columns]

# %% [markdown]
# # Correlação
#
# O dataset é composto de variáveis categóricas e númericas, por isso é necessário fazer um tratamento especifico para cada par de variáveis de tipos diferentes.

# %%
X_tr_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 950 entries, 615 to 1126
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             950 non-null    int64
#  1   MSSubClass     950 non-null    int64
#  2   MSZoning       950 non-null    object
#  3   LotFrontage    950 non-null    float64
#  4   LotArea        950 non-null    int64
#  5   Street         950 non-null    object
#  6   LotShape       950 non-null    object
#  7   LandContour    950 non-null    object
#  8   Utilities      950 non-null    object
#  9   LotConfig      950 non-null    object
#  10  LandSlope      950 non-null    object
#  11  Neighborhood   950 non-null    object
#  12  Condition1     950 non-null    object
#  13  Condition2     950 non-null    object
#  14  BldgType       950 non-null    object
#  15  HouseStyle     950 non-null    object
#  16  OverallQual    950 non-null    int64
#  17  OverallCond    950 non-null    int64
#  18  YearBuilt      950 non-null    int64
#  19  YearRemodAdd   950 non-null    int64
#  20  RoofStyle      950 non-null    object
#  21  RoofMatl       950 non-null    object
#  22  Exterior1st    950 non-null    object
#  23  Exterior2nd    950 non-null    object
#  24  MasVnrType     950 non-null    object
#  25  MasVnrArea     950 non-null    float64
#  26  ExterQual      950 non-null    object
#  27  ExterCond      950 non-null    object
#  28  Foundation     950 non-null    object
#  29  BsmtQual       950 non-null    object
#  30  BsmtCond       950 non-null    object
#  31  BsmtExposure   950 non-null    object
#  32  BsmtFinType1   950 non-null    object
#  33  BsmtFinSF1     950 non-null    int64
#  34  BsmtFinType2   950 non-null    object
#  35  BsmtFinSF2     950 non-null    int64
#  36  BsmtUnfSF      950 non-null    int64
#  37  TotalBsmtSF    950 non-null    int64
#  38  Heating        950 non-null    object
#  39  HeatingQC      950 non-null    object
#  40  CentralAir     950 non-null    object
#  41  Electrical     950 non-null    object
#  42  1stFlrSF       950 non-null    int64
#  43  2ndFlrSF       950 non-null    int64
#  44  LowQualFinSF   950 non-null    int64
#  45  GrLivArea      950 non-null    int64
#  46  BsmtFullBath   950 non-null    int64
#  47  BsmtHalfBath   950 non-null    int64
#  48  FullBath       950 non-null    int64
#  49  HalfBath       950 non-null    int64
#  50  BedroomAbvGr   950 non-null    int64
#  51  KitchenAbvGr   950 non-null    int64
#  52  KitchenQual    950 non-null    object
#  53  TotRmsAbvGrd   950 non-null    int64
#  54  Functional     950 non-null    object
#  55  Fireplaces     950 non-null    int64
#  56  FireplaceQu    950 non-null    object
#  57  GarageType     950 non-null    object
#  58  GarageYrBlt    950 non-null    float64
#  59  GarageFinish   950 non-null    object
#  60  GarageCars     950 non-null    int64
#  61  GarageArea     950 non-null    int64
#  62  GarageQual     950 non-null    object
#  63  GarageCond     950 non-null    object
#  64  PavedDrive     950 non-null    object
#  65  WoodDeckSF     950 non-null    int64
#  66  OpenPorchSF    950 non-null    int64
#  67  EnclosedPorch  950 non-null    int64
#  68  3SsnPorch      950 non-null    int64
#  69  ScreenPorch    950 non-null    int64
#  70  PoolArea       950 non-null    int64
#  71  Fence          950 non-null    object
#  72  MiscVal        950 non-null    int64
#  73  MoSold         950 non-null    int64
#  74  YrSold         950 non-null    int64
#  75  SaleType       950 non-null    object
#  76  SaleCondition  950 non-null    object
# dtypes: float64(3), int64(34), object(40)
# memory usage: 578.9+ KB

# %%
categoric_cols = X_tr_o.select_dtypes(include='object')
numeric_cols = X_tr_o.select_dtypes(exclude='object')
categoric_cols
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 615        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 613        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1303       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 486        RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 561        RL   Pave      Reg         Lvl    AllPub    Inside       Mod
# ...       ...    ...      ...         ...       ...       ...       ...
# 1095       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 1130       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1294       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 860        RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 1126       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Functional FireplaceQu  \
# 615         NAmes      Feedr       Norm  ...        Typ     Inexist
# 613       Mitchel      Feedr       Norm  ...        Typ     Inexist
# 1303      Somerst       Norm       Norm  ...        Typ     Inexist
# 486         NAmes       Norm       Norm  ...        Typ     Inexist
# 561       Mitchel       Norm       Norm  ...        Typ          TA
# ...           ...        ...        ...  ...        ...         ...
# 1095      CollgCr       Norm       Norm  ...        Typ          Gd
# 1130        SWISU       Norm       Norm  ...       Min2          TA
# 1294      Edwards       Norm       Norm  ...        Typ     Inexist
# 860       Crawfor       Norm       Norm  ...        Typ          Gd
# 1126      Blmngtn       Norm       Norm  ...        Typ          TA
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive    Fence  \
# 615      Attchd          RFn         TA         TA          Y    MnPrv
# 613     Inexist      Inexist    Inexist    Inexist          Y  Inexist
# 1303     Attchd          RFn         TA         TA          Y  Inexist
# 486      Attchd          RFn         TA         TA          Y  Inexist
# 561      Attchd          RFn         TA         TA          Y  Inexist
# ...         ...          ...        ...        ...        ...      ...
# 1095     Attchd          RFn         TA         TA          Y  Inexist
# 1130     Detchd          Unf         TA         TA          Y    MnPrv
# 1294     Detchd          Unf         TA         TA          N  Inexist
# 860      Detchd          Unf         TA         TA          Y    GdPrv
# 1126     Attchd          Fin         TA         TA          Y  Inexist
#
#      SaleType SaleCondition
# 615        WD       Abnorml
# 613       New       Partial
# 1303       WD        Normal
# 486        WD        Normal
# 561        WD        Normal
# ...       ...           ...
# 1095       WD        Normal
# 1130       WD        Normal
# 1294       WD        Normal
# 860        WD        Normal
# 1126       WD        Normal
#
# [950 rows x 40 columns]

# %% [markdown]
# Será feito o seguinte tratamento para os tipos de variáveis, entre:
#
# - Númericas e categóricas: **Correlation_Ratio**
#
# - Categóricas: **Cramers-V**
#
# - Númericas: Persons

# %%
def correlation_ratio(categories, measurements):
    fcat, _ = pd.factorize(categories.reset_index(drop=True))
    cat_num = np.max(fcat)+1
    y_avg_array = np.zeros(cat_num)
    n_array = np.zeros(cat_num)
    for i in range(0,cat_num):
        cat_measures = measurements.reset_index(drop=True)[np.argwhere(fcat == i).flatten()]
        n_array[i] = len(cat_measures)
        y_avg_array[i] = np.average(cat_measures)
    y_total_avg = np.sum(np.multiply(y_avg_array,n_array))/np.sum(n_array)
    numerator = np.sum(np.multiply(n_array,np.power(np.subtract(y_avg_array,y_total_avg),2)))
    denominator = np.sum(np.power(np.subtract(measurements,y_total_avg),2))
    if numerator == 0:
        eta = 0.0
    else:
        eta = np.sqrt(numerator/denominator)
    return eta


import scipy.stats as ss
def cramers_v(x, y):
  confusion_matrix = pd.crosstab(x,y)
  chi2 = ss.chi2_contingency(confusion_matrix)[0]
  n = confusion_matrix.sum().sum()
  phi2 = chi2/n
  r,k = confusion_matrix.shape
  phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
  rcorr = r-((r-1)**2)/(n-1)
  kcorr = k-((k-1)**2)/(n-1)
  return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
cor_df = pd.DataFrame(columns=X_tr_o.columns,index=X_tr_o.columns)
cor_num_vs_cat = pd.DataFrame(columns=numeric_cols.columns,index=categoric_cols.columns)
cor_num_vs_num = pd.DataFrame(columns=numeric_cols.columns,index=numeric_cols.columns)
cor_cat_vs_cat = pd.DataFrame(columns=categoric_cols.columns,index=categoric_cols.columns)
cols_analysed = []

for col,dtypes_col in X_tr_o.dtypes.items():
  for index,dtypes_idx in X_tr_o.dtypes.items():
    if ([col,index] in cols_analysed) or ([index,col] in cols_analysed):
      
      continue
    else:
      #Entre uma categorica e uma numerica
      if (dtypes_col == 'object' and dtypes_idx != 'object') or (dtypes_idx == 'object' and dtypes_col != 'object'):

        if (dtypes_col == 'object' and dtypes_idx != 'object'):
          cor = correlation_ratio(X_tr_o[col], X_tr_o[index])
          cor_num_vs_cat.loc[col,index] = cor
        elif (dtypes_idx == 'object' and dtypes_col != 'object'):
          cor = correlation_ratio(X_tr_o[index], X_tr_o[col])
        
          cor_num_vs_cat.loc[index,col] = cor

      #Entre duas categóricas
      elif dtypes_col == 'object' and dtypes_idx == 'object':
        cor = cramers_v(X_tr_o[col], X_tr_o[index])
        cor_cat_vs_cat.loc[index,col] = cor
      
      #Entre duas numéricas
      else:
        cor = X_tr_o[col].corr(X_tr_o[index],method='pearson')
        cor_num_vs_num.loc[index,col] = cor

      cols_analysed.append([col,index])
      cor_df.loc[index,col] = cor

cor_df = cor_df.astype('float64')
cor_cat_vs_cat = cor_cat_vs_cat.astype('float64')
cor_num_vs_cat = cor_num_vs_cat.astype('float64')
cor_num_vs_num = cor_num_vs_num.astype('float64')
cor_df
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000         NaN       NaN          NaN       NaN
# MSSubClass    -0.002614    1.000000       NaN          NaN       NaN
# MSZoning       0.077156    0.359680  1.000000          NaN       NaN
# LotFrontage   -0.022275   -0.214608  0.122736     1.000000       NaN
# LotArea       -0.045058   -0.121794  0.189445     0.088984  1.000000
# ...                 ...         ...       ...          ...       ...
# MiscVal        0.038684    0.000129  0.038302    -0.054770  0.067766
# MoSold        -0.005872   -0.003371  0.104637     0.015383  0.002017
# YrSold        -0.012492   -0.038678  0.034217    -0.022857 -0.002876
# SaleType       0.078249    0.148880  0.147794     0.226757  0.037628
# SaleCondition  0.053172    0.080650  0.127271     0.221896  0.038449
#
#                  Street  LotShape  LandContour  Utilities  LotConfig  ...  \
# Id                  NaN       NaN          NaN        NaN        NaN  ...
# MSSubClass          NaN       NaN          NaN        NaN        NaN  ...
# MSZoning            NaN       NaN          NaN        NaN        NaN  ...
# LotFrontage         NaN       NaN          NaN        NaN        NaN  ...
# LotArea             NaN       NaN          NaN        NaN        NaN  ...
# ...                 ...       ...          ...        ...        ...  ...
# MiscVal        0.033254  0.039446     0.026047   0.003828   0.021756  ...
# MoSold         0.008075  0.049041     0.091187   0.065266   0.033791  ...
# YrSold         0.022695  0.024723     0.042954   0.029386   0.037355  ...
# SaleType       0.000000  0.000000     0.052755   0.170438   0.000000  ...
# SaleCondition  0.000000  0.000000     0.075928   0.094098   0.028344  ...
#
#                EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea     Fence  \
# Id                       NaN        NaN          NaN       NaN       NaN
# MSSubClass               NaN        NaN          NaN       NaN       NaN
# MSZoning                 NaN        NaN          NaN       NaN       NaN
# LotFrontage              NaN        NaN          NaN       NaN       NaN
# LotArea                  NaN        NaN          NaN       NaN       NaN
# ...                      ...        ...          ...       ...       ...
# MiscVal             0.065113   0.007406     0.091651  0.082132  0.083015
# MoSold             -0.054276   0.046974     0.022240 -0.029793  0.058573
# YrSold             -0.020439   0.013531     0.029339 -0.066044  0.100050
# SaleType            0.153703   0.043176     0.079577  0.031235  0.034679
# SaleCondition       0.133682   0.037457     0.075467  0.375341  0.077450
#
#                 MiscVal    MoSold    YrSold  SaleType  SaleCondition
# Id                  NaN       NaN       NaN       NaN            NaN
# MSSubClass          NaN       NaN       NaN       NaN            NaN
# MSZoning            NaN       NaN       NaN       NaN            NaN
# LotFrontage         NaN       NaN       NaN       NaN            NaN
# LotArea             NaN       NaN       NaN       NaN            NaN
# ...                 ...       ...       ...       ...            ...
# MiscVal        1.000000       NaN       NaN       NaN            NaN
# MoSold         0.015689  1.000000       NaN       NaN            NaN
# YrSold         0.020138 -0.144817  1.000000       NaN            NaN
# SaleType       0.042228  0.107237  0.148085   1.00000            NaN
# SaleCondition  0.047968  0.081049  0.153621   0.47627            1.0
#
# [77 rows x 77 columns]

# %% [markdown]
# ### Correlação entre as variáveis categóricas
#
# Usarei aqui método **Cramers-V**, em que a correlação varia de 0 (nada correlacionada) à 1 (inteiramente correlacionada). Ou seja, não possui valores negativos como a correlação que já conhecemos

# %%
plt.figure(figsize=(20,20))
sn.heatmap(cor_cat_vs_cat.round(6),annot=True, square=True, fmt='.2f',annot_kws={'size':9},  cmap= "coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Correlação entre variáveis continuas e categóricas
#
# Correlation Ratio - O cálculo baseia-se na comparação entre a dipersão da variável númerica Y dado uma categoria X e a dispersão total de Y da população total.
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(20,20))
sn.heatmap(cor_num_vs_cat.round(6),annot=True, square=True, fmt='.2f',annot_kws={'size':9},  cmap= "coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Correlação entre variáveis contínuas

# %%
plt.figure(figsize=(20,20))
sn.heatmap(cor_num_vs_num.round(6),annot=True, square=True, fmt='.2f',annot_kws={'size':9},  cmap= "coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Excluindo as colunas correlacionadas
#
# Aqui usarei o função mutual_info_regression do sklearn. O cálculo consiste basicamente na estimação de entropia nas distancias dos k-vizinhos.
# Não usei o Teste F para testar a covariância neste caso, pois este teste só reconhece depedência linear, enquanto o mutual_info_regression reconhece qualquer tipo de dependência.
#
# Fonte: https://scikit-learn.org/stable/auto_examples/feature_selection/plot_f_test_vs_mi.html

# %%
from sklearn.feature_selection import mutual_info_regression

X_tr_corr = X_tr_enc.copy()
X_ts_corr = X_ts_enc.copy()


dropped = []

for num1,col1 in enumerate(cor_df.columns):
    if col1 in dropped: 
        continue # Pule se a coluna 1 já foi dropada
    for num2,col2 in enumerate(cor_df.index):
        if col1 in dropped:
            break # Pare se a coluna 1 já foi dropada
        if col2 in dropped:
            continue # Continue se a coluna 2 já foi dropada
        if num2 <= num1: 
            continue # Continue se estou olhando para a diagonal inferior da matriz
        if col1==col2:
            continue # Continue se estou olhando para a diagonal da matriz. Pois sempre serão terão corr == 1
        val = cor_df.loc[col2,col1]
        if abs(val) < .7:  # Continue se o valor da correção entre col2 e col1 foi inferior a esse
            continue
            
        
        #mutual_info_classif(y_train.values.reshape(-1,1),y_train)y_train_enc
        imm1 = mutual_info_regression(X_tr_corr[[col1]],np.ravel(y_tr))
        imm2 = mutual_info_regression(X_tr_corr[[col2]],np.ravel(y_tr))
        
        if imm1 > imm2:
            dropped.append(col2.strip())
            print(f'Entre {col1} e {col2}, descartamos {col2}')
        else:
            dropped.append(col1.strip())
            print(f'Entre {col1} e {col2}, descartamos {col1}')


X_tr_corr = X_tr_corr.drop(dropped, axis=1)
X_ts_corr = X_ts_corr.drop(dropped, axis=1)
# Out:
# Entre MSSubClass e BldgType, descartamos BldgType
# Entre Neighborhood e OverallQual, descartamos Neighborhood
# Entre Condition2 e MiscVal, descartamos Condition2
# Entre HouseStyle e 2ndFlrSF, descartamos HouseStyle
# Entre YearBuilt e Foundation, descartamos Foundation
# Entre YearBuilt e BsmtQual, descartamos BsmtQual
# Entre Exterior1st e Exterior2nd, descartamos Exterior2nd
# Entre BsmtFinType2 e BsmtFinSF2, descartamos BsmtFinType2
# Entre TotalBsmtSF e 1stFlrSF, descartamos TotalBsmtSF
# Entre GrLivArea e TotRmsAbvGrd, descartamos TotRmsAbvGrd
# Entre Fireplaces e FireplaceQu, descartamos Fireplaces
# Entre GarageType e GarageYrBlt, descartamos GarageType
# Entre GarageYrBlt e GarageFinish, descartamos GarageFinish
# Entre GarageYrBlt e GarageQual, descartamos GarageQual
# Entre GarageYrBlt e GarageCond, descartamos GarageCond
# Entre GarageCars e GarageArea, descartamos GarageArea

# %%
plt.plot(X_tr_o.groupby('YearBuilt').EnclosedPorch.mean())

# %% [markdown]
# A correlação entre yearbiult e bairro decorre-se a expansão dos bairros ao decorrer dos anos

# %%
plt.figure(figsize=(10,5))
plt.plot(X_tr_o['YearBuilt'],X_tr_o['Neighborhood'],'.')
plt.xticks(rotation=90);

# %% [markdown]
# # Feature Selection
#
# Para seleção das variáveis mais importantes

# %% [markdown]
# ## LASSO LARS

# %%
from sklearn.linear_model import LassoLarsCV

reg = LassoLarsCV(fit_intercept=True,cv=5, normalize=True)
reg.fit(X_tr_corr, y_tr)
# Out:
# LassoLarsCV(cv=5, normalize=True)

# %% [markdown]
# ### Avaliação

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

y_pred = reg.predict(X_ts_corr)


print('MAE: ',mean_absolute_error(y_ts, y_pred),mean_absolute_error(y_ts, y_pred)/y_pred.mean())
print('MSE: ',mean_squared_error(y_ts, y_pred,squared=False),mean_squared_error(y_ts, y_pred)/y_pred.mean())


# Com correlação
# MAE:  27008.727607765464 0.152595257462053
# MSE:  60359.56226907547 20583.966888838564

# SEM CORRELAÇÃO
# MAE:  26408.487546878576 0.1491584807576586
# MSE:  59057.82929072074 19699.689558256006
# Out:
# MAE:  25526.91313416463 0.14374241778611174
# MSE:  58972.145430588746 19583.05757536847

# %% [markdown]
# Existe uma GRANDE diferença entre as métricas MAE E MSE. Isso geralmente se da por conta de outliers na variável resposta.
#
# Vamos dar uma olhada...

# %% [markdown]
# ### Coeficientes

# %%
df_coefs = pd.DataFrame(np.column_stack((X_tr_corr.columns,reg.coef_)),columns=['features','coefs'])
only_important = df_coefs[df_coefs.coefs.abs() > 0]
only_important.sort_values('coefs', ascending=False)
# Out:
#         features         coefs
# 12   OverallQual  31824.355694
# 36     GrLivArea  23789.446953
# 21     ExterQual  13514.048566
# 47    GarageCars  12731.448989
# 43   KitchenQual   9327.369465
# 37  BsmtFullBath   6720.637794
# 14     YearBuilt   4603.251095
# 26    BsmtFinSF1   4209.727405
# 24  BsmtExposure   3989.767963
# 15  YearRemodAdd   3910.958167
# 45   FireplaceQu   2549.099101
# 20    MasVnrArea   2420.322607
# 49    WoodDeckSF   1948.740513
# 33      1stFlrSF    1565.80507
# 4        LotArea      942.8508
# 53   ScreenPorch     23.345336
# 54      PoolArea    -48.684763
# 1     MSSubClass  -6529.707099

# %% [markdown]
# ### Análise dos erros

# %% [markdown]
# Os erros não estão se distribuindo de forma normal. Provavelmente umproblema de outliers

# %%
def normal(x,m,s):
    return 1/(np.sqrt(2*np.pi)*s) * np.exp((-1/2) * ((x-m)/s)**2)

plt.figure(figsize=(15,5))
res = y_pred-y_ts
plt.hist(res, bins=50, rwidth=.8, density=True)
plt.plot(np.linspace(res.min(),res.max(),100), normal(np.linspace(res.min(),res.max(),100),res.mean(), res.std(ddof=1)), 'k-', lw=3);

# %% [markdown]
# # Regressão Linear
# Com as features relevantes

# %%
from sklearn.linear_model import LinearRegression
column = only_important.features.unique()
lr = LinearRegression(normalize=True, fit_intercept=True, positive=False)
lr.fit(X_tr_corr[column], y_tr)
# Out:
# C:\Users\lippe\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# LinearRegression(normalize=True)

# %% [markdown]
# ### Avaliação

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

y_pred = lr.predict(X_ts_corr[column])


print('MAE: ',mean_absolute_error(y_ts, y_pred))
print('RMSE: ',mean_squared_error(y_ts, y_pred,squared=False))

# SEM CORRELAÇÃO
# MAE:  31988.153602093367
# RMSE:  66011.31829987536

# COM CORRELAÇÃO
# MAE:  29935.304771453517
# RMSE:  62839.579917926145
# Out:
# MAE:  30006.19038654721
# RMSE:  70083.40065247277

# %% [markdown]
# ### Coeficientes

# %% [markdown]
# Agora que estamos com os betas ótimos para minimização dos erros, vamos analisa-los

# %%
df_coefs_lr = pd.DataFrame(np.column_stack((column,lr.coef_)),columns=['features','coefs'])

df_coefs_lr.sort_values('coefs', ascending=False)
# Out:
#         features         coefs
# 2    OverallQual  29998.486589
# 10     GrLivArea  27505.391739
# 6      ExterQual  15198.684201
# 14    GarageCars  12226.611336
# 11  BsmtFullBath  10167.521202
# 12   KitchenQual   9388.895812
# 4   YearRemodAdd    6912.00557
# 3      YearBuilt   6451.353112
# 8     BsmtFinSF1   5592.356189
# 7   BsmtExposure   5132.754452
# 15    WoodDeckSF   4024.961267
# 5     MasVnrArea   3582.303766
# 13   FireplaceQu   3038.793367
# 1        LotArea    1474.85587
# 16   ScreenPorch     79.469371
# 17      PoolArea   -166.213554
# 9       1stFlrSF  -1344.445962
# 0     MSSubClass -10598.922875

# %% [markdown]
# A variável que mais impacta positivamente é a **OverallQual**	o que faz todo o sentido. Quanto melhor a qualidade em geral, maior o preço.
#
# Algumas variáveis vieram com correlação negativa, vamos analisar se realmente faz sentido dado nosso problema

# %%
df.MSSubClass.value_counts(dropna=False).sort_index()
# Out:
# 20     536
# 30      69
# 40       4
# 45      12
# 50     144
# 60     299
# 70      60
# 75      16
# 80      58
# 85      20
# 90      52
# 120     87
# 160     63
# 180     10
# 190     30
# Name: MSSubClass, dtype: int64

# %%
plt.figure(figsize=(10,5))
sn.boxplot(data = df,x='MSSubClass',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %% [markdown]
# Não está muito claro se existe uma correlação dessa variável com a resposta. Talvez esse viés negativo seja por conta da menor amostra de casas com o MSSubClass maiores

# %%
plt.figure(figsize=(10,5))
sn.countplot(data = df,x='MSSubClass')
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='count'>

# %% [markdown]
# ### 1stFlrSF - First Floor square feet
#
# Aqui é possível observar que existe uma correlação positiva entre 1stFlrSF e SalePrice. Porém, muito provavelmente seu outlier (o ponto com área > 4000) pesou muito resultando em uma correlação negativa no modelo.

# %%
plt.figure(figsize=(10,5))
sn.scatterplot(data = df,x='1stFlrSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
plt.figure(figsize=(10,5))
sn.histplot(data = df,x='1stFlrSF')
# Out:
# <AxesSubplot:xlabel='1stFlrSF', ylabel='Count'>

# %% [markdown]
# ### PoolArea

# %%
plt.figure(figsize=(10,5))
sn.scatterplot(data = df,x='PoolArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='PoolArea', ylabel='SalePrice'>

# %%
plt.figure(figsize=(10,5))
sn.histplot(data = df,x='PoolArea')
# Out:
# <AxesSubplot:xlabel='PoolArea', ylabel='Count'>

# %% [markdown]
# Essa variável não está nada balanceada. A correlação negativa é decorrente principalmente pela amostragem reduzida.

# %% [markdown]
# ## Modeling
#
# Observamos que as variáveis não fazem sentido, tanto para a área de negócio quanto estatisticamente em nosso modelo, que sejam negativamente correlacionadas com a variável resposta. Dessa forma, irei habilitar o parâmetro **positive** do sklearn, em que impõe restrições a regressão para que os betas não sejam negativos.

# %%
from sklearn.linear_model import LinearRegression
column = only_important.features.unique()
lr_o = LinearRegression(normalize=True, fit_intercept=True, positive=True)
lr_o.fit(X_tr_corr[column], y_tr)
# Out:
# C:\Users\lippe\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# LinearRegression(normalize=True, positive=True)

# %% [markdown]
# ## Avaliação

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

y_pred_out = lr_o.predict(X_ts_corr[column])

mae_metrics = round(mean_absolute_error(y_ts, y_pred_out),2)
mse_metrics = round(mean_squared_error(y_ts, y_pred_out,squared=False),2)

print('MAE: ', mae_metrics)
print('MSE: ', mse_metrics)

# SEM CORRELAÇÂO
# MAE:  23482.49
# MSE:  29226.32


# COM Correlação
# MAE:  21677.74
# MSE:  25753.41
# Out:
# MAE:  23712.27
# MSE:  54888.47

# %% [markdown]
# Tivemos uma melhora significativa no modelo somente ligando o parâmetro!

# %% [markdown]
# ### Análise dos resíduos

# %%
def normal(x,m,s):
    return 1/(np.sqrt(2*np.pi)*s) * np.exp((-1/2) * ((x-m)/s)**2)

plt.figure(figsize=(15,5))
res = y_pred_out-y_ts
plt.hist(res, bins=100, rwidth=.8, density=True)
plt.plot(np.linspace(res.min(),res.max(),100), normal(np.linspace(res.min(),res.max(),100),res.mean(), res.std(ddof=1)), 'k-', lw=3);

# %% [markdown]
# Se pudermos prever quais casas tem o valor exorbitante, talvez vale tratarmos manualmente esses casos de outliers

# %% [markdown]
# # Outliers - Variável resposta

# %%
y_tr.describe()
# Out:
# count       950.000000
# mean     183009.321053
# std       76062.292348
# min       34900.000000
# 25%      132312.500000
# 50%      165500.000000
# 75%      219125.000000
# max      625000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# O cálculo para identificação desses valores é através da 1,5 * FIQ (Interquartil) do conjunto de TREINO e aplicado ao conjunto teste.

# %%
outlier_max = y_tr.quantile(0.75) + 1.5*(y_tr.quantile(0.75) - y_tr.quantile(0.25))
outlier_idx = y_tr[y_tr > outlier_max].index

# %% [markdown]
# Lembrando que o outlier foi calculado através do método 1.5 FIQ. O limite entre uma observação normal e um outliers é:

# %%
outlier_max
# Out:
# 349343.75

# %% [markdown]
# Temos uma total de 3% da variável dependente considerado outliter

# %%
y_tr_classif = y_tr.apply(lambda x:1 if x >= outlier_max else 0)
y_ts_classif = y_ts.apply(lambda x:1 if x >= outlier_max else 0)
y_tr_classif.mean()
# Out:
# 0.03894736842105263

# %% [markdown]
# # Anomaly detection
#
# Regressão logística na previsão de outliers na variável resposta.

# %% [markdown]
# ### Ordinal Encode

# %%
from sklearn.preprocessing import OrdinalEncoder
X_tr_enc_anom = X_tr_o.copy()
X_ts_enc_anom = X_ts_o.copy()

encoder = {}
default_cat = ['Po', 'Fa', 'TA', 'Gd', 'Ex']
for col,dtype in X_tr_enc_anom.dtypes.items():
    if dtype == 'object':
      encoder[col] = OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value= -1,categories=[default_cat])
      X_tr_enc_anom.loc[:,col] = encoder[col].fit_transform(X_tr_enc_anom[[col]],)
      X_ts_enc_anom.loc[:,col] = encoder[col].transform(X_ts_enc_anom[[col]])

X_tr_enc_anom
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 615    616          85      -1.0         80.0     8800    -1.0      -1.0
# 613    614          20      -1.0         70.0     8402    -1.0      -1.0
# 1303  1304          20      -1.0         73.0     8688    -1.0      -1.0
# 486    487          20      -1.0         79.0    10289    -1.0      -1.0
# 561    562          20      -1.0         77.0    10010    -1.0      -1.0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1095  1096          20      -1.0         78.0     9317    -1.0      -1.0
# 1130  1131          50      -1.0         65.0     7804    -1.0      -1.0
# 1294  1295          20      -1.0         60.0     8172    -1.0      -1.0
# 860    861          50      -1.0         55.0     7642    -1.0      -1.0
# 1126  1127         120      -1.0         53.0     3684    -1.0      -1.0
#
#       LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# 615          -1.0       -1.0       -1.0  ...              0          0
# 613          -1.0       -1.0       -1.0  ...              0          0
# 1303         -1.0       -1.0       -1.0  ...              0          0
# 486          -1.0       -1.0       -1.0  ...              0          0
# 561          -1.0       -1.0       -1.0  ...              0          0
# ...           ...        ...        ...  ...            ...        ...
# 1095         -1.0       -1.0       -1.0  ...              0          0
# 1130         -1.0       -1.0       -1.0  ...              0          0
# 1294         -1.0       -1.0       -1.0  ...              0          0
# 860          -1.0       -1.0       -1.0  ...              0          0
# 1126         -1.0       -1.0       -1.0  ...              0          0
#
#       ScreenPorch  PoolArea  Fence  MiscVal  MoSold  YrSold  SaleType  \
# 615             0         0   -1.0        0       5    2010      -1.0
# 613             0         0   -1.0        0      12    2007      -1.0
# 1303            0         0   -1.0        0       4    2006      -1.0
# 486             0         0   -1.0        0       6    2007      -1.0
# 561             0         0   -1.0        0       4    2006      -1.0
# ...           ...       ...    ...      ...     ...     ...       ...
# 1095            0         0   -1.0        0       3    2007      -1.0
# 1130            0         0   -1.0        0      12    2009      -1.0
# 1294            0         0   -1.0        0       4    2006      -1.0
# 860             0         0   -1.0        0       6    2007      -1.0
# 1126            0         0   -1.0        0       6    2009      -1.0
#
#       SaleCondition
# 615            -1.0
# 613            -1.0
# 1303           -1.0
# 486            -1.0
# 561            -1.0
# ...             ...
# 1095           -1.0
# 1130           -1.0
# 1294           -1.0
# 860            -1.0
# 1126           -1.0
#
# [950 rows x 77 columns]

# %% [markdown]
# ### Otimização dos Hiperparêmtros

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV


params = {
    'criterion': ['gini','entropy'],
    'max_depth': [7,9,11,13,15],   
}


rf = GridSearchCV(
    RandomForestClassifier(n_estimators= 100,n_jobs= 4),
    params,
    cv=5,
    scoring= 'roc_auc',
    verbose=10
)

# %%
rf.fit(X_tr_enc_anom,y_tr_classif)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=gini, max_depth=7................................
# [CV 1/5; 1/10] END .criterion=gini, max_depth=7;, score=0.993 total time=   0.0s
# [CV 2/5; 1/10] START criterion=gini, max_depth=7................................
# [CV 2/5; 1/10] END .criterion=gini, max_depth=7;, score=0.989 total time=   0.0s
# [CV 3/5; 1/10] START criterion=gini, max_depth=7................................
# [CV 3/5; 1/10] END .criterion=gini, max_depth=7;, score=0.952 total time=   0.0s
# [CV 4/5; 1/10] START criterion=gini, max_depth=7................................
# [CV 4/5; 1/10] END .criterion=gini, max_depth=7;, score=0.977 total time=   0.0s
# [CV 5/5; 1/10] START criterion=gini, max_depth=7................................
# [CV 5/5; 1/10] END .criterion=gini, max_depth=7;, score=0.988 total time=   0.0s
# [CV 1/5; 2/10] START criterion=gini, max_depth=9................................
# [CV 1/5; 2/10] END .criterion=gini, max_depth=9;, score=0.990 total time=   0.0s
# [CV 2/5; 2/10] START criterion=gini, max_depth=9................................
# [CV 2/5; 2/10] END .criterion=gini, max_depth=9;, score=0.990 total time=   0.0s
# [CV 3/5; 2/10] START criterion=gini, max_depth=9................................
# [CV 3/5; 2/10] END .criterion=gini, max_depth=9;, score=0.962 total time=   0.0s
# [CV 4/5; 2/10] START criterion=gini, max_depth=9................................
# [CV 4/5; 2/10] END .criterion=gini, max_depth=9;, score=0.984 total time=   0.0s
# [CV 5/5; 2/10] START criterion=gini, max_depth=9................................
# [CV 5/5; 2/10] END .criterion=gini, max_depth=9;, score=0.990 total time=   0.0s
# [CV 1/5; 3/10] START criterion=gini, max_depth=11...............................
# [CV 1/5; 3/10] END criterion=gini, max_depth=11;, score=0.995 total time=   0.0s
# [CV 2/5; 3/10] START criterion=gini, max_depth=11...............................
# [CV 2/5; 3/10] END criterion=gini, max_depth=11;, score=0.990 total time=   0.0s
# [CV 3/5; 3/10] START criterion=gini, max_depth=11...............................
# [CV 3/5; 3/10] END criterion=gini, max_depth=11;, score=0.966 total time=   0.0s
# [CV 4/5; 3/10] START criterion=gini, max_depth=11...............................
# [CV 4/5; 3/10] END criterion=gini, max_depth=11;, score=0.971 total time=   0.0s
# [CV 5/5; 3/10] START criterion=gini, max_depth=11...............................
# [CV 5/5; 3/10] END criterion=gini, max_depth=11;, score=0.986 total time=   0.0s
# [CV 1/5; 4/10] START criterion=gini, max_depth=13...............................
# [CV 1/5; 4/10] END criterion=gini, max_depth=13;, score=0.993 total time=   0.0s
# [CV 2/5; 4/10] START criterion=gini, max_depth=13...............................
# [CV 2/5; 4/10] END criterion=gini, max_depth=13;, score=0.993 total time=   0.0s
# [CV 3/5; 4/10] START criterion=gini, max_depth=13...............................
# [CV 3/5; 4/10] END criterion=gini, max_depth=13;, score=0.900 total time=   0.0s
# [CV 4/5; 4/10] START criterion=gini, max_depth=13...............................
# [CV 4/5; 4/10] END criterion=gini, max_depth=13;, score=0.973 total time=   0.0s
# [CV 5/5; 4/10] START criterion=gini, max_depth=13...............................
# [CV 5/5; 4/10] END criterion=gini, max_depth=13;, score=0.990 total time=   0.0s
# [CV 1/5; 5/10] START criterion=gini, max_depth=15...............................
# [CV 1/5; 5/10] END criterion=gini, max_depth=15;, score=0.991 total time=   0.0s
# [CV 2/5; 5/10] START criterion=gini, max_depth=15...............................
# [CV 2/5; 5/10] END criterion=gini, max_depth=15;, score=0.993 total time=   0.0s
# [CV 3/5; 5/10] START criterion=gini, max_depth=15...............................
# [CV 3/5; 5/10] END criterion=gini, max_depth=15;, score=0.961 total time=   0.0s
# [CV 4/5; 5/10] START criterion=gini, max_depth=15...............................
# [CV 4/5; 5/10] END criterion=gini, max_depth=15;, score=0.974 total time=   0.0s
# [CV 5/5; 5/10] START criterion=gini, max_depth=15...............................
# [CV 5/5; 5/10] END criterion=gini, max_depth=15;, score=0.986 total time=   0.0s
# [CV 1/5; 6/10] START criterion=entropy, max_depth=7.............................
# [CV 1/5; 6/10] END criterion=entropy, max_depth=7;, score=0.992 total time=   0.0s
# [CV 2/5; 6/10] START criterion=entropy, max_depth=7.............................
# [CV 2/5; 6/10] END criterion=entropy, max_depth=7;, score=0.989 total time=   0.0s
# [CV 3/5; 6/10] START criterion=entropy, max_depth=7.............................
# [CV 3/5; 6/10] END criterion=entropy, max_depth=7;, score=0.949 total time=   0.0s
# [CV 4/5; 6/10] START criterion=entropy, max_depth=7.............................
# [CV 4/5; 6/10] END criterion=entropy, max_depth=7;, score=0.982 total time=   0.0s
# [CV 5/5; 6/10] START criterion=entropy, max_depth=7.............................
# [CV 5/5; 6/10] END criterion=entropy, max_depth=7;, score=0.988 total time=   0.0s
# [CV 1/5; 7/10] START criterion=entropy, max_depth=9.............................
# [CV 1/5; 7/10] END criterion=entropy, max_depth=9;, score=0.993 total time=   0.0s
# [CV 2/5; 7/10] START criterion=entropy, max_depth=9.............................
# [CV 2/5; 7/10] END criterion=entropy, max_depth=9;, score=0.989 total time=   0.0s
# [CV 3/5; 7/10] START criterion=entropy, max_depth=9.............................
# [CV 3/5; 7/10] END criterion=entropy, max_depth=9;, score=0.897 total time=   0.0s
# [CV 4/5; 7/10] START criterion=entropy, max_depth=9.............................
# [CV 4/5; 7/10] END criterion=entropy, max_depth=9;, score=0.977 total time=   0.0s
# [CV 5/5; 7/10] START criterion=entropy, max_depth=9.............................
# [CV 5/5; 7/10] END criterion=entropy, max_depth=9;, score=0.988 total time=   0.0s
# [CV 1/5; 8/10] START criterion=entropy, max_depth=11............................
# [CV 1/5; 8/10] END criterion=entropy, max_depth=11;, score=0.989 total time=   0.0s
# [CV 2/5; 8/10] START criterion=entropy, max_depth=11............................
# [CV 2/5; 8/10] END criterion=entropy, max_depth=11;, score=0.991 total time=   0.0s
# [CV 3/5; 8/10] START criterion=entropy, max_depth=11............................
# [CV 3/5; 8/10] END criterion=entropy, max_depth=11;, score=0.954 total time=   0.0s
# [CV 4/5; 8/10] START criterion=entropy, max_depth=11............................
# [CV 4/5; 8/10] END criterion=entropy, max_depth=11;, score=0.971 total time=   0.0s
# [CV 5/5; 8/10] START criterion=entropy, max_depth=11............................
# [CV 5/5; 8/10] END criterion=entropy, max_depth=11;, score=0.990 total time=   0.0s
# [CV 1/5; 9/10] START criterion=entropy, max_depth=13............................
# [CV 1/5; 9/10] END criterion=entropy, max_depth=13;, score=0.990 total time=   0.0s
# [CV 2/5; 9/10] START criterion=entropy, max_depth=13............................
# [CV 2/5; 9/10] END criterion=entropy, max_depth=13;, score=0.993 total time=   0.0s
# [CV 3/5; 9/10] START criterion=entropy, max_depth=13............................
# [CV 3/5; 9/10] END criterion=entropy, max_depth=13;, score=0.963 total time=   0.0s
# [CV 4/5; 9/10] START criterion=entropy, max_depth=13............................
# [CV 4/5; 9/10] END criterion=entropy, max_depth=13;, score=0.981 total time=   0.0s
# [CV 5/5; 9/10] START criterion=entropy, max_depth=13............................
# [CV 5/5; 9/10] END criterion=entropy, max_depth=13;, score=0.991 total time=   0.0s
# [CV 1/5; 10/10] START criterion=entropy, max_depth=15...........................
# [CV 1/5; 10/10] END criterion=entropy, max_depth=15;, score=0.987 total time=   0.0s
# [CV 2/5; 10/10] START criterion=entropy, max_depth=15...........................
# [CV 2/5; 10/10] END criterion=entropy, max_depth=15;, score=0.988 total time=   0.0s
# [CV 3/5; 10/10] START criterion=entropy, max_depth=15...........................
# [CV 3/5; 10/10] END criterion=entropy, max_depth=15;, score=0.895 total time=   0.0s
# [CV 4/5; 10/10] START criterion=entropy, max_depth=15...........................
# [CV 4/5; 10/10] END criterion=entropy, max_depth=15;, score=0.975 total time=   0.0s
# [CV 5/5; 10/10] START criterion=entropy, max_depth=15...........................
# [CV 5/5; 10/10] END criterion=entropy, max_depth=15;, score=0.987 total time=   0.0s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=4),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [7, 9, 11, 13, 15]},
#              scoring='roc_auc', verbose=10)

# %%
rf.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=13, n_jobs=4)

# %% [markdown]
# ### Predição e avaliação

# %%
from sklearn.metrics import roc_auc_score

y_pred_ts = rf.predict(X_ts_enc_anom)
y_pred_tr = rf.predict(X_tr_enc_anom)

roc_auc_score(y_ts_classif,y_pred)
# Out:
# 1.0

# %% [markdown]
# Aparentemete os dados estão sendo separados perfeitamente. Talvez exista um padrão para os preços dos outliers na base

# %%
plt.figure(figsize=(10,5))
plt.hist(y_pred_ts[y_ts_classif == 1],bins=30,rwidth=0.9,alpha=0.6,density=True)
plt.hist(y_pred_ts[y_ts_classif == 0],bins=30,rwidth=0.9,alpha=0.6,density=True);

# %%
from sklearn.metrics import recall_score


roc_auc_score(y_ts_classif,y_pred)
# Out:
# 1.0

# %%
feature_importance = pd.DataFrame(np.column_stack((X_ts_enc_anom.columns,rf.best_estimator_.feature_importances_)),columns=['columns','importance'])
feature_importance[feature_importance.importance > 0].sort_values('importance',ascending=False)
# Out:
#           columns importance
# 42       1stFlrSF   0.083136
# 37    TotalBsmtSF   0.081595
# 29       BsmtQual   0.081234
# 16    OverallQual   0.077525
# 45      GrLivArea   0.069821
# 60     GarageCars   0.056739
# 33     BsmtFinSF1   0.043712
# 61     GarageArea   0.036183
# 19   YearRemodAdd   0.033481
# 18      YearBuilt   0.033449
# 4         LotArea   0.032423
# 53   TotRmsAbvGrd   0.029338
# 26      ExterQual   0.028887
# 58    GarageYrBlt   0.028341
# 43       2ndFlrSF   0.027746
# 36      BsmtUnfSF   0.025936
# 25     MasVnrArea   0.025197
# 56    FireplaceQu   0.023331
# 3     LotFrontage   0.021791
# 52    KitchenQual   0.015617
# 0              Id   0.013902
# 50   BedroomAbvGr   0.013463
# 73         MoSold    0.01331
# 55     Fireplaces   0.012198
# 65     WoodDeckSF   0.012024
# 66    OpenPorchSF   0.011407
# 31   BsmtExposure   0.011148
# 1      MSSubClass    0.00818
# 74         YrSold   0.008149
# 48       FullBath   0.008023
# 46   BsmtFullBath   0.007503
# 17    OverallCond   0.005062
# 49       HalfBath   0.004281
# 69    ScreenPorch   0.003094
# 62     GarageQual   0.001902
# 27      ExterCond   0.001895
# 39      HeatingQC   0.001725
# 35     BsmtFinSF2   0.001458
# 68      3SsnPorch   0.001421
# 44   LowQualFinSF   0.001268
# 47   BsmtHalfBath   0.001085
# 30       BsmtCond   0.000973
# 67  EnclosedPorch   0.000317
# 70       PoolArea   0.000275
# 51   KitchenAbvGr   0.000233
# 63     GarageCond   0.000226

# %%
X_tr_corr['outlier'] = y_pred_tr
X_ts_corr['outlier'] = y_pred_ts
X_tr_corr
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 615  -0.152159         0.7      -1.0        0.425 -0.194446    -1.0      -1.0
# 613  -0.154817        -0.6      -1.0        0.175 -0.291183    -1.0      -1.0
# 1303  0.762126        -0.6      -1.0        0.250 -0.221669    -1.0      -1.0
# 486  -0.323588        -0.6      -1.0        0.400  0.167467    -1.0      -1.0
# 561  -0.223920        -0.6      -1.0        0.350  0.099654    -1.0      -1.0
# ...        ...         ...       ...          ...       ...     ...       ...
# 1095  0.485714        -0.6      -1.0        0.375 -0.068785    -1.0      -1.0
# 1130  0.532226         0.0      -1.0        0.050 -0.436532    -1.0      -1.0
# 1294  0.750166        -0.6      -1.0       -0.075 -0.347086    -1.0      -1.0
# 860   0.173422         0.0      -1.0       -0.200 -0.475907    -1.0      -1.0
# 1126  0.526910         1.4      -1.0       -0.250 -1.437929    -1.0      -1.0
#
#       LandContour  Utilities  LotConfig  ...  3SsnPorch  ScreenPorch  \
# 615          -1.0       -1.0       -1.0  ...        0.0          0.0
# 613          -1.0       -1.0       -1.0  ...        0.0          0.0
# 1303         -1.0       -1.0       -1.0  ...        0.0          0.0
# 486          -1.0       -1.0       -1.0  ...        0.0          0.0
# 561          -1.0       -1.0       -1.0  ...        0.0          0.0
# ...           ...        ...        ...  ...        ...          ...
# 1095         -1.0       -1.0       -1.0  ...        0.0          0.0
# 1130         -1.0       -1.0       -1.0  ...        0.0          0.0
# 1294         -1.0       -1.0       -1.0  ...        0.0          0.0
# 860          -1.0       -1.0       -1.0  ...        0.0          0.0
# 1126         -1.0       -1.0       -1.0  ...        0.0          0.0
#
#       PoolArea  Fence  MiscVal    MoSold  YrSold  SaleType  SaleCondition  \
# 615        0.0   -1.0      0.0 -0.333333     1.0      -1.0           -1.0
# 613        0.0   -1.0      0.0  2.000000    -0.5      -1.0           -1.0
# 1303       0.0   -1.0      0.0 -0.666667    -1.0      -1.0           -1.0
# 486        0.0   -1.0      0.0  0.000000    -0.5      -1.0           -1.0
# 561        0.0   -1.0      0.0 -0.666667    -1.0      -1.0           -1.0
# ...        ...    ...      ...       ...     ...       ...            ...
# 1095       0.0   -1.0      0.0 -1.000000    -0.5      -1.0           -1.0
# 1130       0.0   -1.0      0.0  2.000000     0.5      -1.0           -1.0
# 1294       0.0   -1.0      0.0 -0.666667    -1.0      -1.0           -1.0
# 860        0.0   -1.0      0.0  0.000000    -0.5      -1.0           -1.0
# 1126       0.0   -1.0      0.0  0.000000     0.5      -1.0           -1.0
#
#       outlier
# 615         0
# 613         0
# 1303        0
# 486         0
# 561         0
# ...       ...
# 1095        0
# 1130        0
# 1294        0
# 860         0
# 1126        0
#
# [950 rows x 62 columns]

# %% [markdown]
# # Treinando o modelo
# Com a coluna de previsão de outliers

# %%
from sklearn.linear_model import LinearRegression
column = only_important.features.unique()
lr_anom = LinearRegression(normalize=True, fit_intercept=True, positive=True)
lr_anom.fit(X_tr_corr[np.append(column,'outlier')], y_tr)
# Out:
# C:\Users\lippe\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# LinearRegression(normalize=True, positive=True)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

y_pred_anom = lr_anom.predict(X_ts_corr[np.append(column,'outlier')])


print('MAE: ',mean_absolute_error(y_ts, y_pred_anom))
print('RMSE: ',mean_squared_error(y_ts, y_pred_anom,squared=False))
# Out:
# MAE:  23430.177089075394
# RMSE:  44293.24856853501

# %%
RMSE_anom = mean_squared_error(y_ts, y_pred_anom,squared=False)
RMSE = mse_metrics

print(f'A redução nos erros foi de {round((RMSE_anom - RMSE)/RMSE*100,2)}% para RMSE')
# Out:
# A redução nos erros foi de -19.3% para RMSE

# %% [markdown]
# ### Análise dos residuos

# %% [markdown]
# #### Conjunto Treino

# %%
plt.figure(figsize=(15,5))
y_pred_tr = lr_anom.predict(X_tr_corr[np.append(column,'outlier')])
res = y_pred_tr-y_tr
plt.hist(res, bins=100, rwidth=.8, density=True)
plt.plot(np.linspace(res.min(),res.max(),100), normal(np.linspace(res.min(),res.max(),100),res.mean(), res.std(ddof=1)), 'k-', lw=3);

# %% [markdown]
# #### Conjunto teste

# %%
plt.figure(figsize=(15,5))
res = y_pred-y_ts
plt.hist(res, bins=100, rwidth=.8, density=True)
plt.plot(np.linspace(res.min(),res.max(),100), normal(np.linspace(res.min(),res.max(),100),res.mean(), res.std(ddof=1)), 'k-', lw=3);

# %% [markdown]
# ## Tranformação logaritma da variável resposta

# %%
def normal(x,m,s):
    return 1/(np.sqrt(2*np.pi)*s) * np.exp((-1/2) * ((x-m)/s)**2)

plt.figure(figsize=(10,5))
plt.hist(y_tr, bins =list(range(y_tr.min(),y_tr.max(),20000)),rwidth=0.9,density=True)
plt.plot(np.linspace(y_tr.min(),y_tr.max(),20000), normal(np.linspace(y_tr.min(),y_tr.max(),20000),y_tr.mean(), y_tr.std(ddof=1)),
         'k-', lw=3);

# %%
from sklearn.compose import TransformedTargetRegressor
regressor = LinearRegression(fit_intercept=True, positive=True)

tt = TransformedTargetRegressor(regressor=regressor,func=np.log, inverse_func=np.exp)
tt.fit(X_tr_corr[np.append(column,'outlier')], y_tr)
# Out:
# TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression(positive=True))

# %% [markdown]
# ## Avaliação

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

y_pred_tt = tt.predict(X_ts_corr[np.append(column,'outlier')])

print('MAE: ',mean_absolute_error(y_ts, y_pred_tt))
print('RMSE: ',mean_squared_error(y_ts, y_pred_tt,squared=False))
print('')


# MAE:  21582.27531774511
# RMSE:  36029.38259098918
# Out:
# MAE:  20604.9680299633
# RMSE:  28098.430619526254

# %%
RMSE_anom = mean_squared_error(y_ts, y_pred_anom,squared=False)
RMSE = mean_squared_error(y_ts, y_pred_tt,squared=False)

print(f'A redução nos erros foi de {round((RMSE_anom - RMSE)/RMSE*100,2)}% para RMSE')
# Out:
# A redução nos erros foi de 57.64% para RMSE

# %%
plt.figure(figsize=(15,5))
res = y_pred_tt-y_ts
plt.hist(res, bins=100, rwidth=.8, density=True)
plt.plot(np.linspace(res.min(),res.max(),100), normal(np.linspace(res.min(),res.max(),100),res.mean(), res.std(ddof=1)), 'k-', lw=3);

# %% [markdown]
# A casa de maior valor é a que puxa o maior erro no conjunto teste

# %%
print(y_ts[res < -100_000].values,y_pred_anom[res < -100_000])

print(f'erro de: {y_ts[res < -100_000].values - y_pred_anom[res < -100_000]}')
# Out:
# [745000] [492679.21715896]
# erro de: [252320.78284104]

# %% [markdown]
# Porém, como mandamos um modelo para detectar casas com valores discrepantes. Como identificamos que a casa anterior seria um outlier, poderia apontar isso para o usuário não depender das predições do modelo, mas sim para uma análise mais manual

# %%
X_ts_corr.loc[y_ts[res < -100_000].index,'outlier']
# Out:
# 1182    1
# Name: outlier, dtype: int64

# %%
df_coefs_lr = pd.DataFrame(np.column_stack((np.append(column,'outlier'),tt.regressor_.coef_)),columns=['features','coefs'])
df_coefs_lr.sort_values('coefs', ascending=False)
# Out:
#         features     coefs
# 18       outlier  0.210769
# 2    OverallQual  0.148198
# 10     GrLivArea    0.1101
# 3      YearBuilt  0.087506
# 14    GarageCars  0.087247
# 4   YearRemodAdd  0.077287
# 11  BsmtFullBath  0.051246
# 12   KitchenQual  0.025952
# 13   FireplaceQu  0.023587
# 15    WoodDeckSF  0.021662
# 9       1stFlrSF  0.012881
# 1        LotArea  0.008428
# 8     BsmtFinSF1  0.006668
# 7   BsmtExposure   0.00648
# 16   ScreenPorch  0.000431
# 6      ExterQual       0.0
# 5     MasVnrArea       0.0
# 17      PoolArea       0.0
# 0     MSSubClass       0.0

# %% [markdown]
# # Análise para a negócios
#
# Das variáveis mais importantes temos:
#
# - OverallQual: A variável que mais impacta no preço.
# - YearBuilt: O ano em que a casa foi construída impacta bastante o preço das casas. Isso decorre provavelmente por conta da qualidade média das casas cair com o decorrer do tempo e casas em que foi recentemente contruída estão em bairros em expansão, o que valoriza o redor das casas.
# - GrLivArea: Area de pisos com qualidade acima da média.

# %% [markdown]
# ### OverallQual

# %%
qual_grouped = df.groupby('OverallQual')['SalePrice'].mean().reset_index()
qual_grouped
# Out:
#    OverallQual      SalePrice
# 0            1   50150.000000
# 1            2   51770.333333
# 2            3   87473.750000
# 3            4  108420.655172
# 4            5  133523.347607
# 5            6  161603.034759
# 6            7  207716.423197
# 7            8  274735.535714
# 8            9  367513.023256
# 9           10  438588.388889

# %%
plt.figure(figsize=(10,5))
sn.barplot(x = qual_grouped.OverallQual, y = qual_grouped.SalePrice, data= qual_grouped)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Yearbuilt

# %% [markdown]
# É possível observar que quanto mais recente as casas foram construídas, mais elevado o preço médio

# %%
plt.figure(figsize=(15,5))
year_grouped = df.groupby('YearBuilt')['SalePrice'].mean().reset_index()

sn.barplot(x = year_grouped.YearBuilt, y = year_grouped.SalePrice, data= year_grouped)
plt.xticks(rotation=90)
plt.show()

# %%
neigh_grouped = df.groupby('Neighborhood')['YearBuilt'].median().sort_values(ascending = False).reset_index()
neigh_grouped['SalesPrice'] = neigh_grouped.Neighborhood.apply(lambda x : df.groupby('Neighborhood')['SalePrice'].mean()[x] if pd.isna(x) == False else 0)
neigh_grouped['SalesPrice'] = neigh_grouped.Neighborhood.apply(lambda x : df.groupby('Neighborhood')['SalePrice'].mean()[x] if pd.isna(x) == False else 0)
neigh_grouped['Percent_Sales'] = neigh_grouped.SalesPrice.apply(lambda x: x/neigh_grouped.SalesPrice.sum())
neigh_grouped['Age'] = neigh_grouped.YearBuilt.apply(lambda x: neigh_grouped.YearBuilt.max() - x)
neigh_grouped['porcent_Age'] = neigh_grouped.Age.apply(lambda x: x/neigh_grouped.Age.sum())

# %% [markdown]
# Aqui podemos bairro cujo a idade média das casas são mais avançadas tem preços menores

# %%
plt.figure(figsize=(10,5))
year_grouped = df.groupby('YearBuilt')['SalePrice'].median().reset_index()

sn.barplot(x = neigh_grouped.Neighborhood, y = neigh_grouped.Percent_Sales, data= neigh_grouped,label='preço médio')
sn.lineplot(x = neigh_grouped.Neighborhood, y = neigh_grouped.porcent_Age, data= neigh_grouped,label='idade média')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ### GrLivArea

# %% [markdown]
# A relação não é tão clara para o GrLivArea, mas existe uma correlação positiva dessa variável com a resposta.

# %%
sn.scatterplot(x = df.GrLivArea, y = year_grouped.SalePrice, data= df)
plt.xticks(rotation=90)
plt.show()
